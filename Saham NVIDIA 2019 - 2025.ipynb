# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Nvidia_Market.csv')

# %%
df
# Out:
#            Date       Close        High         Low        Open     Volume
# 0     6/18/2025  145.479996  145.649994  143.119995  144.009995  161494100
# 1     6/17/2025  144.119995  145.220001  143.779999  144.490005  139108000
# 2     6/16/2025  144.690002  146.179993  143.199997  143.350006  183133700
# 3     6/13/2025  141.970001  143.580002  140.850006  142.479996  180820600
# 4     6/12/2025  145.000000  145.000000  141.850006  141.970001  162365000
# ...         ...         ...         ...         ...         ...        ...
# 1501  6/28/2019    4.080895    4.109223    4.034180    4.100029  397668000
# 1502  6/27/2019    4.056048    4.075181    4.007096    4.043127  445440000
# 1503  6/26/2019    3.957398    4.018526    3.878628    3.891549  584072000
# 1504  6/25/2019    3.764075    3.873410    3.761342    3.798367  311868000
# 1505  6/24/2019    3.793396    3.822966    3.745190    3.792402  282948000
#
# [1506 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1506 entries, 0 to 1505
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1506 non-null   object
#  1   Close   1506 non-null   float64
#  2   High    1506 non-null   float64
#  3   Low     1506 non-null   float64
#  4   Open    1506 non-null   float64
#  5   Volume  1506 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 70.7+ KB

# %%
df.isnull().sum()
# Out:
# Date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df_sorted = df.sort_values(by='Date', ascending=True).reset_index(drop=True)
df = df_sorted

# %%
df.describe()
# Out:
#                                 Date        Close         High          Low  \
# count                           1506  1506.000000  1506.000000  1506.000000
# mean   2022-06-18 20:20:04.780876288    42.045388    42.828005    41.184329
# min              2019-06-24 00:00:00     3.696735     3.767803     3.662444
# 25%              2020-12-17 06:00:00    13.056040    13.299466    12.865205
# 50%              2022-06-16 12:00:00    20.781192    21.226867    20.613377
# 75%              2023-12-14 18:00:00    49.048418    49.687359    48.372476
# max              2025-06-18 00:00:00   149.405869   153.105279   147.796143
# std                              NaN    43.502147    44.316733    42.629314
#
#               Open        Volume
# count  1506.000000  1.506000e+03
# mean     42.044407  4.253920e+08
# min       3.724815  9.788400e+07
# 25%      13.044635  2.854490e+08
# 50%      20.912924  3.976610e+08
# 75%      49.333660  5.254240e+08
# max     153.005289  1.543911e+09
# ...

# %% [markdown]
# # Analisa Saham NVIDIA dalam 6 tahun terakhir

# %% [markdown]
# ## Closing Trend NVIDIA

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Close'], color='seagreen', linewidth=2)
plt.title('Trend Closing Price', fontsize=16)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Closing Price', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## Periode Awal (Pertengahan 2019 - Akhir 2022)
# * Harga relatif stabil dan perlahan naik karena tahun tersebut merupakan tahun pandemi `COVID-19`. Maka terjadi lonjakan permintaan untuk laptop, PC, dan server cloud sehingga permintaan GPU `NVIDIA` meningkat.
# * `NVIDIA` juga mengumumkan rencana akuisisi `ARM` yang membuat pasar semakin optimis.
# * Booming `Gaming dan mining Crypto` *(Contoh Game: Genshin Impact, Valorant, COD Warzone, Cyberpunk, dll.)*
#
# `ARM` adalah perusahaan asal Inggris yang desain arsitektur chip-nya dipakai di hampir semua smartphone dan tablet di dunia. Perbedaan antara NVIDIA dan ARM adalah perusahaan NVIDIA berfokus pada **GPU atau (graphics processing unit) dan AI**, sedangkan ARM berfokus kepada **CPU (central processing unit) hemat daya**.
#
# Agar NVIDIA bisa menguasai ekosistem teknologi, maka di tahun 2020 NVIDIA ingin mengaukisisi `ARM` dengan biaya sekitar **$40 miliar**.
#
# `Gaming dan Mining Crypto` terjadi karena pandemi Covid-19 dimana masyarakat pada saat itu tidak bisa keluar seperti biasanya, oleh karena itu mereka memilih ``mining crypto`` untuk menambah penghasilan dan `gaming` untuk melawan bosan.

# %% [markdown]
# ## Anjloknya NVIDIA 2022 - 2023
#
# Berdasarkan grafik `NVIDIA` diperoleh
# * Harga sempat turun tajam.
# * Bisa jadi ini karena ada berita negatif, perubahan fundamental perusahaan, atau koreksi pasar.
#
# Tahun 2022 adalah tahun setelah pandemi `Covid-19`, akibatnya orang yang terbiasa gaming di rumah mulai jenuh dan mulai meninggalkan kebiasaannya di rumah. Tidak hanya itu, penyebab lain dari anjloknya harga saham pada saat itu adalah muncul tanda sebagai berikut.
#
# * Harga Crypto anjlok sehingga mining dengan `NVIDIA` jadi tidak laku.
# * Stok `NVIDIA` menumpuk karena setelah pandemi sudah boleh keluar rumah dan anjloknya harga crypto.
# * Ekonomi melemah yang disebabkan inflasi tinggi, perang Rusia-Ukraina, Bank Sentral menaikkan suku bunga, dan sebagainya.
# * Ada larangan jual GPU ke China.
#
# Berdasarkan tanda tersebut, banyak investor mulai *menjual sahamnya* agar tidak rugi lebih besar. Akibatnya saham dari `NVIDIA` turun di tahun tersebut atau istilahnya **Bubble Correction**.

# %% [markdown]
# ## Masa kebangkitan NVIDIA 2023 - 2024
#
# Setelah ekonomi melemah di 2022, perlahan-lahan kondisi mulai stabil di 2023.
# Apa yang terjadi:
# * Inflasi mulai menurun, walaupun tidak langsung normal.
# * Suku bunga tetap tinggi di awal, tapi mulai ada tanda-tanda pelonggaran di akhir 2023.
# * Supply chain global membaik.
# * Pasar saham mulai rebound (naik lagi).
#
# Berdasarkan grafik, saham `NVIDIA` mengalami kenaikan yang **sangat drastis**. Mengapa hal tersebut bisa terjadi? Jawabannya adalah tren `AI`.
#
# Pada November 2022, `OpenAI` mengumumkan `ChatGPT` untuk pertama kalinya. Karena manfaatnya yang luar biasa, masyarakat menerima dengan sangat baik. Kemudian, karena pasarnya begitu besar, perusahaan lain berlomba-lomba untuk menciptakan `AI` versinya masing-masing. Nah, masalahnya `AI` tersebut bergantung kepada GPU milik `NVIDIA` yaitu GPU `NVIDIA` seri A100 dan H100 adalah yang terbaik saat itu.
#
# Efek dari hal tersebut adalah banyak sekali permintaan GPU tapi produksinya tidak bisa cepat maka terjadi kelangkaan GPU. Karena langka maka harganya mahal, sehingga perusahaan `NVIDIA` untung besar. **Investor** yang mengetahui betapa boomingnya `AI` berlomba-lomba untuk membeli lagi saham `NVIDIA`. Maka dari itulah lonjakan yang terjadi pada tahun tersebut sangat tinggi.

# %% [markdown]
# ## Saham NVIDIA 2024 - Sekarang
#
# Pada tahun 2024, `NVIDIA` mengalami lonjakan saham yang sangat besar. Penyebabnya adalah sebagai berikut.
#
# * Dominasi di bidang AI hardware (GPU), data center, dan cloud computing.
# * Perusahaan seperti Microsoft, Amazon, Google, OpenAI, hingga Tesla semua memakai GPU `NVIDIA`.
# * Banyak perusahaan mengantre untuk beli GPU NVIDIA, seperti seri H100 yang super powerful.
#
# *Tahun 2024 adalah puncak dominasi NVIDIA*.
#
# **Walaupun tampak sempurna, ada risiko besar yang mulai muncul akhir-akhir ini, yaitu:**
# * AMD dan Intel mulai meluncurkan GPU untuk `AI` (misalnya Instinct MI300 & Grace CPU).
# * Google, Amazon, dan Microsoft mulai mengembangkan chip `AI` mereka sendiri.
# * Pemerintah Amerika mulai membatasi ekspor GPU ke China, sehingga potensi kehilangan pasar besar.
#
# Mulai pertengahan 2025, pasar mulai melihat:
# * Apakah pertumbuhan AI masih secepat ini?
# * Apakah persaingan mulai menekan margin NVIDIA?
# * Potensi bubble correction ringan bisa terjadi.

# %% [markdown]
# ## Analisa Closing Trend dengan Simple Moving Average

# %%
df['SMA_20'] = df['Close'].rolling(window=20).mean() #Rata-rata per 20 hari
df['SMA_50'] = df['Close'].rolling(window=50).mean() #Rata-rata per 50 hari
df['SMA_200'] = df['Close'].rolling(window=200).mean() #Rata-rata per 100 hari

plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Close'], color='royalblue', label='Close Price')
plt.plot(df['Date'], df['SMA_20'], color='orange', label='SMA 20 Days', linewidth=2)
plt.plot(df['Date'], df['SMA_50'], color='green', label='SMA 50 Days', linewidth=2)
plt.plot(df['Date'], df['SMA_200'], color='red', label='SMA 200 Days', linewidth=2)
plt.title('Closing Trend Price', fontsize=12)
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## Analisa Simple Moving Average
#
# Simple Moving Average (SMA) adalah metode yang digunakan untuk menentukan nilai rata-rata dari suatu saham. Biasanya metode tersebut memanfaatkan beberapa hari, antara lain tiap 20 hari, 50 hari, bahkan 200 hari. Tujuannya adalah untuk mengikuti tren saham yang sedang dibeli.
#
# **NVIDIA 2020 - 2021**:
# Sentimen pasar cenderung naik (bullish) karena pada saat itu banyak orang beralih ke digital akibat `Covid-19`.
#
# **NVIDIA 2022**:
# Harga mulai diatas SMA20, artinya saham sedang ada penurunan yang diakibatkan oleh beberapa peristiwa di dunia.
#
# **NVIDIA 2023**:
# `OpenAI` mengumumkan `ChatGPT` untuk pertama kalinya, alhasil saham dari `NVIDIA` melonjak tajam hingga akhir tahun. Lonjakan tersebut dapat dilihat pada grafik dimana harga saham banyak yang berada dibawah SMA20 (artinya itu waktu untuk beli).
#
# **NVIDIA 2024**:
# Karena keberhasilannya untuk menciptakan komponen `AI`, maka banyak orang yang FOMO untuk membeli saham **(banyak dibawah SMA20)**. Maka dari itu, pada tahun 2024 meskipun terjadi beberapa penurunan harga saham akan tetapi harga tersebut naik kembali karena banyak yang ikut membeli saham.
#
# **NVIDIA 2025**:
# Pada tahun tersebut sentimen pasar mulai banyak yang menjual saham karena mulai realistis serta profit taking namun mulai naik kembali di pertengahan 2025, terbukti dari banyak grafik yang di atas SMA20 pada awal bulan tahun ini.
#
# ## Insight
# Biasanya, investor sering memanfaatkan SMA50 dengan SMA200 yang dinamakan **Golden Cross** dan **Death Cross**.
# Untuk analisa SMA50 dan SMA200, dapat dibaca pada laman berikut: https://www.investopedia.com/terms/s/sma.asp

# %%
df['Daily_Return'] = df['Close'].pct_change()

plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Daily_Return'], color='seagreen')
plt.title('Daily Return (Persentase Perubahan Harian)', fontsize=12)
plt.xlabel('Tanggal')
plt.ylabel('Daily Return')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## Daily Return NVIDIA 2019 - 2025
#
# `Daily Return` adalah persentase perubahan harga saham dari satu hari ke hari berikutnya. Metode tersebut dilakukan untuk melihat seberapa besar saham naik dan turun setiap harinya. Sedangkan `volatilitas` adalah besar perubahan harga saham tiap hari.
#
# Berdasarkan grafik di atas, daily return pada saham `NVIDIA` mengalami volatilitas yang tinggi pada tahun 2020 awal dan pertengahan 2025.
# Pada tahun 2020 awal terjadi COVID-19 sehingga menyebabkan panic sell & buy.
# Sedangkan pada tahun 2025 terjadi volatilitas tinggi karena hype AI dan mulai profit taking.
#
# Selain itu `Daily Return` saham `NVIDIA` cenderung stabil (Investor cenderung lebih suka yang stabil).

# %%
import plotly.graph_objects as go
import pandas as pd

# Menggunakan Simple Moving Average
df['SMA20'] = df['Close'].rolling(window=20).mean()
df['SMA50'] = df['Close'].rolling(window=50).mean()
df['SMA200'] = df['Close'].rolling(window=200).mean()

# Membuat Candlestick Chart
fig = go.Figure(data=[go.Candlestick(
                x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'],
                name='Candlestick')])

# Menambahkan SMA 20,50, dan 200
fig.add_trace(go.Scatter(
    x=df['Date'],
    y=df['SMA20'],
    mode='lines',
    line=dict(color='blue', width=2),
    name='SMA 20'
))
fig.add_trace(go.Scatter(
    x=df['Date'],
    y=df['SMA50'],
    mode='lines',
    line=dict(color='orange', width=2),
    name='SMA 50'
))
fig.add_trace(go.Scatter(
    x=df['Date'],
    y=df['SMA200'],
    mode='lines',
    line=dict(color='yellow', width=2),
    name='SMA 200'
))

fig.update_layout(title='Candlestick Chart NVIDIA with SMA 20',
                  xaxis_title='Date',
                  yaxis_title='Price',
                  xaxis_rangeslider_visible=False)

fig.show()

# %% [markdown]
# ## Analisa Candle Stick Saham NVIDIA 2021 - 2022
#
# Pada bulan September 2021, terjadi **Golden Cross** yaitu ketika nilai `Moving Average 50` mendekati dari bawah `Moving Average 200` dimana ketika keadaan itu terjadi maka tren akan naik.
#
# Kemudian pada bulan Juni 2022 terjadi **Death Cross**, yaitu keadaan dimana nilai `Moving Average 50` mendekati dari atas `Moving Average 200`. Apabila hal tersebut terjadi maka bersiap untuk sell.
#
# Pola **Candle stick** dari bulan Desember sampai Januari didominasi oleh warna merah (**Bearish Candle**), hal itu mengisyaratkan bahwa tren akan menurun. Candle stick berwarna hijau beberapa ada yang besar, artinya pembeli masih berupaya dan optimis pada saham `NVIDIA`. Tanda berikutnya pada bulan Desember **harga saham dibandingkan SMA20 cenderung menurun** sehingga itu adalah isyarat untuk jual. Hal tersebut terbukti pada awal bulan harga saham mencapai **30 USD**, akhirnya pada bulan Januari saham mencapai **22 USD**.
#
# *Kuncinya adalah ketika **Candle Stick naik tapi Moving Average nya turun**, hati-hati karena bisa jadi akan terjadi penurunan saham.*
#
# ## Analisa Candle Stick Saham NVIDIA Desember 2023 - Januari 2024
#
# Berdasarkan grafik **candle stick** di atas, dari bulan Desember sampai Januari 2024 terjadi kenaikan dari SMA20 serta posisi **candle stick** berada di bawahnya. Artinya saham tersebut akan naik, hal tersebut dibuktikan dari harga berkisar antara **45 - 50 USD** bisa mencapai **60+ USD**.

# %%
# Plot Volatilitas 30 Hari
df['Volatility'] = df['Daily_Return'].rolling(window=30).std()

plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Volatility'], color='darkorange')
plt.title('30-Day Rolling Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Volatility NVIDIA
#
# **Tahun 2020: Volatilitas Sangat Tinggi**
# Volatilitas mencapai puncak sekitar 0.08.
# Kemungkinan besar disebabkan oleh kondisi pandemi COVID-19 yang memicu ketidakpastian global akibatnya harga saham banyak yang naik-turun tajam.
# Ini periode berisiko tinggi dan seringkali menarik bagi trader jangka pendek.
#
# **Tahun 2021: Volatilitas Mulai Stabil**
# Setelah lonjakan di 2020, volatilitas menurun dan stabil di kisaran 0.02 - 0.03.
# Biasanya, fase ini disebut konsolidasi atau penyesuaian harga mulai bergerak lebih normal.
#
# **Tahun 2022 - 2023: Volatilitas Meningkat Bertahap**
# Terjadi beberapa lonjakan volatilitas secara bertahap.
# Mungkin terkait dengan:
# * Ketegangan geopolitik (misalnya: perang Rusia-Ukraina)
# * Kenaikan suku bunga
# * Penyesuaian pasar setelah lonjakan 2021
#
# **Tahun 2024 - 2025: Fluktuasi Naik Turun Cepat**
# Volatilitas terlihat mulai aktif naik-turun dengan lebih tajam.
# Bisa jadi ini dipengaruhi oleh:
# * Tren AI dan GPU yang sangat cepat berubah.
# * Lonjakan harga saham NVIDIA yang besar-besaran biasanya diikuti volatilitas tinggi.
# * Sentimen pasar AI dan data center yang menjadi hype.

# %%
import matplotlib.pyplot as plt

# Hitung Daily Return
df['Daily_Return'] = df['Close'].pct_change()

# Plot Histogram Return
plt.figure(figsize=(12,6))
plt.hist(df['Daily_Return'].dropna(), bins=100, color='skyblue', edgecolor='black')
plt.title('Histogram of Daily Returns')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Histogram Daily Returns NVIDIA
#
# Berdasarkan histogram, terlihat bahwa cenderung sedikit ke kanan, artinya resiko untuk saham tersebut termasuk **cukup aman**, meskipun terkadang terpengaruh sentimen atau berita yang beredar.

# %%
import seaborn as sns

plt.figure(figsize=(12,6))
sns.scatterplot(x='Volume', y='Close', data=df, color='seagreen')
plt.title('Hubungan Volume dan Closing Price')
plt.xlabel('Volume')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()

# %%
correlation = df['Volume'].corr(df['Close'])
print(f'Korelasi antara Volume dan Closing Price: {correlation:.4f}')

# Visualisasi Korelasi
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Volume', y='Close', data=df)
plt.title(f'Scatter Plot Volume vs Closing Price\nKorelasi: {correlation:.4f}')
plt.xlabel('Volume')
plt.ylabel('Closing Price')
plt.show()

# Deteksi Outlier Menggunakan IQR
Q1 = df['Volume'].quantile(0.25)
Q3 = df['Volume'].quantile(0.75)
IQR = Q3 - Q1

# Batas atas dan bawah
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Jumlah Outlier
outliers = df[(df['Volume'] < lower_bound) | (df['Volume'] > upper_bound)]
print(f'Jumlah Outlier Volume: {outliers.shape[0]}')

# Plot Outlier
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Volume'])
plt.title('Boxplot Volume (Deteksi Outlier)')
plt.show()

# Visualisasi Outlier di Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Volume', y='Close', data=df, label='Data Normal')
sns.scatterplot(x=outliers['Volume'], y=outliers['Close'], color='red', label='Outlier')
plt.title('Scatter Plot Volume vs Closing Price dengan Outlier')
plt.xlabel('Volume')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
# Out:
# Korelasi antara Volume dan Closing Price: -0.2934
# Jumlah Outlier Volume: 32

# %% [markdown]
# ## Volume dan Closing Price
# Closing Price saham NVIDIA menunjukkan tren naik jangka panjang yang kuat, meski diselingi koreksi signifikan. Volume transaksi **tidak selalu menjadi indikator kuat untuk pergerakan harga (korelasi 0.2)**, karena peran sentimen dan berita sangat dominan.
#
# Outlier dalam return harian memberikan sinyal penting akan hari-hari ekstrem, baik dalam peluang breakout maupun potensi risiko besar. Kombinasi analisis close, volume, dan return ekstrem sangat penting dalam memahami perilaku pasar saham NVIDIA dan menyusun strategi yang responsif.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

df_reg = df
df_reg['SMA_20'] = df_reg['Close'].rolling(window=20).mean()
df_reg['Lag_1'] = df_reg['Close'].shift(1)
df_reg['Daily_Return'] = df_reg['Close'].pct_change()

# Drop baris yang kosong
df_reg.dropna(inplace=True)

# Persiapan data untuk Linear Regression
X = df_reg[['Lag_1', 'SMA_20', 'Volume']]
y = df_reg['Close']

# Split data: 80% training, 20% testing
split = int(0.8 * len(df_reg))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Buat model dan training
model = LinearRegression()
model.fit(X_train, y_train)

# Prediksi
y_pred = model.predict(X_test)

# Evaluasi model
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print(f"MAPE: {mape:.2f}%")
print(f"MAE: {mae}")
print(f"RMSE: {rmse}")

# Visualisasi hasil prediksi
plt.figure(figsize=(12, 6))
plt.plot(df_reg['Date'][split:], y_test, label='Actual Price', color='green')
plt.plot(df_reg['Date'][split:], y_pred, label='Predicted Price', color='red')
plt.title('Actual vs Predicted Closing Price')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid()
plt.show()
# Out:
# MAPE: 2.68%
# MAE: 3.180608510574726
# RMSE: 4.292117030759417

# %%
future_predictions = []
last_known = df_reg.iloc[-1].copy()

for i in range(30):
    lag_1 = last_known['Close']
    
    # Update SMA_20
    sma_20 = df_reg['Close'].iloc[-19:].tolist() + future_predictions  # ambil 19 nilai terakhir + prediksi sebelumnya
    sma_20 = np.mean(sma_20[-20:])
    
    # Ambil volume terakhir (anggap tidak berubah)
    volume = last_known['Volume']
    
    # Buat input prediksi hari ke-i
    X_future = np.array([[lag_1, sma_20, volume]])
    y_future = model.predict(X_future)[0]
    
    # Simpan hasil
    future_predictions.append(y_future)
    
    # Update last_known untuk prediksi berikutnya
    last_known['Close'] = y_future  # hasil jadi lag_1 berikutnya

# Tampilkan hasil prediksi
for i, price in enumerate(future_predictions, start=1):
    print(f"Prediksi Hari ke-{i}: {price:.2f}")
future_dates = pd.date_range(start=df_reg['Date'].iloc[-1] + pd.Timedelta(days=1), periods=30, freq='B')
plt.figure(figsize=(10,5))
plt.plot(df_reg['Date'], df_reg['Close'], label='Historical')
plt.plot(future_dates, future_predictions, label='Forecast 30 Hari', color='red', marker='o')
plt.title('Forecast Linear Regression 30 Hari')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Prediksi Hari ke-1: 145.90
# Prediksi Hari ke-2: 146.32
# Prediksi Hari ke-3: 146.74
# Prediksi Hari ke-4: 147.17
# Prediksi Hari ke-5: 147.61
# Prediksi Hari ke-6: 148.04
# Prediksi Hari ke-7: 148.49
# Prediksi Hari ke-8: 148.93
# Prediksi Hari ke-9: 149.38
# Prediksi Hari ke-10: 149.83
# Prediksi Hari ke-11: 150.28
# Prediksi Hari ke-12: 150.74
# Prediksi Hari ke-13: 151.20
# Prediksi Hari ke-14: 151.65
# Prediksi Hari ke-15: 152.11
# Prediksi Hari ke-16: 152.58
# Prediksi Hari ke-17: 153.04
# Prediksi Hari ke-18: 153.50
# Prediksi Hari ke-19: 153.97
# Prediksi Hari ke-20: 154.44
# Prediksi Hari ke-21: 154.91
# Prediksi Hari ke-22: 155.38
# Prediksi Hari ke-23: 155.86
# Prediksi Hari ke-24: 156.34
# Prediksi Hari ke-25: 156.81
# Prediksi Hari ke-26: 157.29
# Prediksi Hari ke-27: 157.78
# Prediksi Hari ke-28: 158.26
# Prediksi Hari ke-29: 158.75
# Prediksi Hari ke-30: 159.23
# ...

# %% [markdown]
# ## Linear Regression Saham NVIDIA
#
# Berdasarkan hasil dari prediksi, saham `NVIDIA` akan mengalami peningkatan hingga **160 USD**.
# Metode Linear Regression sebenarnya **tidak cocok untuk saham,** karena metode tersebut **sangat sensitif dengan outlier**. Oleh karena itu, salah satu metode yang bisa dipakai adalah forecast dengan Prophet seperti contoh di bawah ini.

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

# Data
prophet_df = df[['Date', 'Close']].rename(columns={'Date': 'ds', 'Close': 'y'})
prophet_df['ds'] = pd.to_datetime(prophet_df['ds'])

# Buat dan latih model
model_prophet = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=False)
model_prophet.fit(prophet_df)

# Forecast 30 hari ke depan
future = model_prophet.make_future_dataframe(periods=30, freq='B')
forecast = model_prophet.predict(future)

# Filter
last_date = prophet_df['ds'].max()
forecast_30 = forecast[forecast['ds'] > last_date][['ds', 'yhat']].reset_index(drop=True)

# Tampilkan nilai prediksi
print("📈 Forecast Closing Price 30 Hari ke Depan:")
print(forecast_30)

# Visualisasi
fig = model_prophet.plot(forecast)
plt.title('Forecast Closing Price 30 Hari ke Depan')
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.grid(True)
plt.show()
# Ambil hanya tanggal dan nilai prediksi
forecast_subset = forecast[['ds', 'yhat']]

# Gabungkan prediksi dan aktual berdasarkan tanggal
merged = pd.merge(test, forecast_subset, on='ds')

# Hitung evaluasi
y_true = merged['y'].values
y_pred = merged['yhat'].values

from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100

print(f" MAE  : {mae:.2f}")
print(f" RMSE : {rmse:.2f}")
print(f" MAPE : {mape:.2f}%")
# Out:
# 10:08:33 - cmdstanpy - INFO - Chain [1] start processing
# 10:08:34 - cmdstanpy - INFO - Chain [1] done processing
# 📈 Forecast Harga Penutupan 30 Hari ke Depan:
#            ds        yhat
# 0  2025-06-19  144.697564
# 1  2025-06-20  144.722352
# 2  2025-06-23  144.773582
# 3  2025-06-24  144.766493
# 4  2025-06-25  144.806170
# 5  2025-06-26  144.979307
# 6  2025-06-27  145.066496
# 7  2025-06-30  145.387499
# 8  2025-07-01  145.483579
# 9  2025-07-02  145.625448
# 10 2025-07-03  145.895240
# 11 2025-07-04  146.069166
# 12 2025-07-07  146.552441
# 13 2025-07-08  146.659721
# 14 2025-07-09  146.787832
# 15 2025-07-10  147.017912
# 16 2025-07-11  147.125981
# 17 2025-07-14  147.265047
# 18 2025-07-15  147.216012
# 19 2025-07-16  147.172428
# 20 2025-07-17  147.219562
# 21 2025-07-18  147.138012
# 22 2025-07-21  146.717999
# 23 2025-07-22  146.502860
# 24 2025-07-23  146.311504
# 25 2025-07-24  146.233653
# 26 2025-07-25  146.053864
# 27 2025-07-28  145.529521
# ...

# %% [markdown]
# ## Insight:
#
# Berdasarkan metode `Prophet`, nilai saham `NVIDIA` dalam 30 hari ke depan akan meningkat. Model tersebut di evaluasi dengan MAE, RMSE, dan MAPE.
#
# * MAE: 10.14 artinya nilai prediksi kemungkinan salah adalah 10 USD
# * RMSE: 12.05 artinya nilai dari RMSE di sini lebih tinggi dari MAE karena beberapa prediksi mungkin meleset cukup jauh.
# * MAPE: 8.48% artinya ukuran akurasi dalam bentuk persentase dari harga aktual (**metode cukup bagus**).

# %% [markdown]
# # KESIMPULAN
#
# Berdasarkan analisis penutupan harga, volatilitas, dan forecasting model, saham `NVIDIA` menunjukkan tren kenaikan jangka panjang yang kuat, didorong oleh posisinya sebagai pemimpin industri `AI` dan data center.
# * Volatilitas yang meningkat di tahun 2020 dan 2023 menandakan sensitivitas pasar terhadap krisis global dan hype teknologi.
# * Meskipun prediksi jangka pendek memiliki fluktuasi, model `Prophet` mendukung arah positif jangka menengah hingga panjang.
# * Untuk investor jangka panjang, NVIDIA tetap menjadi saham yang menjanjikan, namun tetap harus waspada terhadap risiko koreksi jangka pendek dan bubble hype teknologi.
# * Dalam forecast menggunakan `Prophet` untuk 30 hari ke depan, saham `NVIDIA` akan meningkat, akan tetapi metode ini perlu diteliti kembali karena nilai MAPE adalah **8.48%**.
